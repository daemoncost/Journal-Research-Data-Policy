# %%
# %load_ext autoreload
# %autoreload 2

# %%
from daemon_analysis_tools.io.yaml_handler import save_answers_to_yaml, load_answers_from_yaml

# %%
grouped_questions = load_answers_from_yaml('../../data/processed/all_answers_backup')

print(grouped_questions)
# Out:
# ['../../data/processed/all_answers_backup/ACS', '../../data/processed/all_answers_backup/AIP', '../../data/processed/all_answers_backup/APS', '../../data/processed/all_answers_backup/Bentham Science', '../../data/processed/all_answers_backup/Elsevier', '../../data/processed/all_answers_backup/Frontiers', '../../data/processed/all_answers_backup/IEEE', '../../data/processed/all_answers_backup/IOP', '../../data/processed/all_answers_backup/MDPI', '../../data/processed/all_answers_backup/Optica', '../../data/processed/all_answers_backup/Pleiades Publishing', '../../data/processed/all_answers_backup/RSC', '../../data/processed/all_answers_backup/Springer Nature', '../../data/processed/all_answers_backup/Taylor & Francis', '../../data/processed/all_answers_backup/Wiley', '../../data/processed/all_answers_backup/open journals']
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# ACS/applied_materials_and_interfaces/data_recommended has inconsistencies: skipped
# ACS/applied_materials_and_interfaces/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/physics_of_fluids/data_recommended Mismatch in discrepancy flags: False, True
# AIP/physics_of_fluids/data_recommended has inconsistencies: skipped
# AIP/physics_of_fluids/data_required Mismatch in discrepancy flags: False, True
# AIP/physics_of_fluids/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/applied_physics_reviews/data_recommended Mismatch in discrepancy flags: False, True
# AIP/applied_physics_reviews/data_recommended has inconsistencies: skipped
# AIP/applied_physics_reviews/data_required Mismatch in discrepancy flags: False, True
# AIP/applied_physics_reviews/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/review_of_scientific_instruments/data_recommended Mismatch in discrepancy flags: False, True
# AIP/review_of_scientific_instruments/data_recommended has inconsistencies: skipped
# AIP/review_of_scientific_instruments/data_required Mismatch in discrepancy flags: False, True
# AIP/review_of_scientific_instruments/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/physics_of_plasmas/data_recommended Mismatch in discrepancy flags: False, True
# AIP/physics_of_plasmas/data_recommended has inconsistencies: skipped
# AIP/physics_of_plasmas/data_required Mismatch in discrepancy flags: False, True
# AIP/physics_of_plasmas/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/chinese_journal_of_chemical_physics/data_recommended Mismatch in discrepancy flags: False, True
# AIP/chinese_journal_of_chemical_physics/data_recommended has inconsistencies: skipped
# AIP/chinese_journal_of_chemical_physics/data_required Mismatch in discrepancy flags: False, True
# AIP/chinese_journal_of_chemical_physics/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/aip_advances/data_recommended Mismatch in discrepancy flags: False, True
# AIP/aip_advances/data_recommended has inconsistencies: skipped
# AIP/aip_advances/data_required Mismatch in discrepancy flags: False, True
# AIP/aip_advances/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/apl_photonics/data_recommended Mismatch in discrepancy flags: False, True
# AIP/apl_photonics/data_recommended has inconsistencies: skipped
# AIP/apl_photonics/data_required Mismatch in discrepancy flags: False, True
# AIP/apl_photonics/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/the_journal_of_chemical_physics/data_recommended Mismatch in discrepancy flags: False, True
# AIP/the_journal_of_chemical_physics/data_recommended has inconsistencies: skipped
# AIP/the_journal_of_chemical_physics/data_required Mismatch in discrepancy flags: False, True
# AIP/the_journal_of_chemical_physics/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/structural_dynamics/data_recommended Mismatch in discrepancy flags: False, True
# AIP/structural_dynamics/data_recommended has inconsistencies: skipped
# AIP/structural_dynamics/data_required Mismatch in discrepancy flags: False, True
# AIP/structural_dynamics/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/journal_of_applied_physics/data_recommended Mismatch in discrepancy flags: False, True
# AIP/journal_of_applied_physics/data_recommended has inconsistencies: skipped
# AIP/journal_of_applied_physics/data_required Mismatch in discrepancy flags: False, True
# AIP/journal_of_applied_physics/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/journal_of_mathematical_physics/data_recommended Mismatch in discrepancy flags: False, True
# AIP/journal_of_mathematical_physics/data_recommended has inconsistencies: skipped
# AIP/journal_of_mathematical_physics/data_required Mismatch in discrepancy flags: False, True
# AIP/journal_of_mathematical_physics/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/applied_physics_letters/data_recommended Mismatch in discrepancy flags: False, True
# AIP/applied_physics_letters/data_recommended has inconsistencies: skipped
# AIP/applied_physics_letters/data_required Mismatch in discrepancy flags: False, True
# AIP/applied_physics_letters/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/apl_materials/data_recommended Mismatch in discrepancy flags: False, True
# AIP/apl_materials/data_recommended has inconsistencies: skipped
# AIP/apl_materials/data_required Mismatch in discrepancy flags: False, True
# AIP/apl_materials/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# AIP/low_temperature_physics/data_recommended Mismatch in discrepancy flags: False, True
# AIP/low_temperature_physics/data_recommended has inconsistencies: skipped
# AIP/low_temperature_physics/data_required Mismatch in discrepancy flags: False, True
# AIP/low_temperature_physics/data_required has inconsistencies: skipped
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# Frontiers/frontiers_in_chemical_engineering/data_recommended Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_recommended in frontiers_in_chemical_engineering/Frontiers
# Frontiers/frontiers_in_chemical_engineering/data_required Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_required in frontiers_in_chemical_engineering/Frontiers
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# Frontiers/frontiers_in_nanotechnology/data_recommended Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_recommended in frontiers_in_nanotechnology/Frontiers
# Frontiers/frontiers_in_nanotechnology/data_required Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_required in frontiers_in_nanotechnology/Frontiers
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# Frontiers/frontiers_in_energy_research/data_recommended Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_recommended in frontiers_in_energy_research/Frontiers
# Frontiers/frontiers_in_energy_research/data_required Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_required in frontiers_in_energy_research/Frontiers
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# Frontiers/frontiers_in_physics/data_recommended Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_recommended in frontiers_in_physics/Frontiers
# Frontiers/frontiers_in_physics/data_required Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_required in frontiers_in_physics/Frontiers
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# Frontiers/frontiers_in_chemistry/data_recommended Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_recommended in frontiers_in_chemistry/Frontiers
# Frontiers/frontiers_in_chemistry/data_required Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_required in frontiers_in_chemistry/Frontiers
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# Frontiers/frontiers_in_bioengineering_and_biotechnology/data_recommended Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_recommended in frontiers_in_bioengineering_and_biotechnology/Frontiers
# Frontiers/frontiers_in_bioengineering_and_biotechnology/data_required Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_required in frontiers_in_bioengineering_and_biotechnology/Frontiers
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# Frontiers/frontiers_in_materials/data_recommended Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_recommended in frontiers_in_materials/Frontiers
# Frontiers/frontiers_in_materials/data_required Mismatch in discrepancy flags: False, True
# Missing discrepancy_reason for data_required in frontiers_in_materials/Frontiers
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# No discrepancies detected.
# ...
# Please name all data types for which unique policies are required according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'code_required': Question(
# 	id='code_required',
# 	text='13. Code sharing requirements',
# 	is_open=False
# ), 'code_reproducibility': Question(
# 	id='code_reproducibility',
# 	text='14. Code Reproducibility',
# 	is_open=False
# ), 'code_versioning': Question(
# 	id='code_versioning',
# 	text='15. Versioning and persistent identifiers',
# 	is_open=False
# ), 'code_quality': Question(
# 	id='code_quality',
# 	text='16. Code Quality Standards',
# 	is_open=False
# ), 'code_autotest': Question(
# 	id='code_autotest',
# 	text='17. Automatic Testing',
# 	is_open=False
# ), 'code_docs': Question(
# 	id='code_docs',
# 	text='18. Code Documentation',
# 	is_open=False
# ), 'code_linting': Question(
# 	id='code_linting',
# 	text='19. Linting Standards',
# 	is_open=False
# ), 'code_development': Question(
# 	id='code_development',
# 	text='20. Code Development',
# 	is_open=False
# )}, 'ce-papers': {'rdp_exist': Question(
# 	id='rdp_exist',
# 	text='1. Existence of research data policy',
# 	is_open=False
# ), 'data_sharing': Question(
# 	id='data_sharing',
# 	text='3. Data sharing requirements in RDP',
# 	is_open=False
# ), 'data_fair': Question(
# 	id='data_fair',
# 	text='4. FAIR data sharing (see https://www.go-fair.org/fair-principles/ for a definition of FAIR)',
# 	is_open=False
# ), 'data_availability': Question(
# 	id='data_availability',
# 	text='2. Data availability statement',
# 	is_open=False
# ), 'data_citability': Question(
# 	id='data_citability',
# 	text='5. Citability and findability of data ',
# 	is_open=False
# ), 'data_timing': Question(
# 	id='data_timing',
# 	text='7. Timing of data release',
# 	is_open=False
# ), 'data_sharing_method': Question(
# 	id='data_sharing_method',
# 	text='8. Recommended data sharing method',
# 	is_open=False
# ), 'data_licenses': Question(
# 	id='data_licenses',
# 	text='9. Recommended/required licenses',
# 	is_open=False
# ), 'data_referee': Question(
# 	id='data_referee',
# 	text='10. Referee guidelines concerning research data',
# 	is_open=False
# ), 'data_recommended': Question(
# 	id='data_recommended',
# 	text='11. Unique policies for data types
# Please name all data types for which unique policies are recommended according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'data_required': Question(
# 	id='data_required',
# 	text='12. Unique policies for data types
# Please name all data types for which unique policies are required according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'code_required': Question(
# 	id='code_required',
# 	text='13. Code sharing requirements',
# 	is_open=False
# ), 'code_reproducibility': Question(
# 	id='code_reproducibility',
# 	text='14. Code Reproducibility',
# 	is_open=False
# ), 'code_versioning': Question(
# 	id='code_versioning',
# 	text='15. Versioning and persistent identifiers',
# 	is_open=False
# ), 'code_quality': Question(
# 	id='code_quality',
# 	text='16. Code Quality Standards',
# 	is_open=False
# ), 'code_autotest': Question(
# 	id='code_autotest',
# 	text='17. Automatic Testing',
# 	is_open=False
# ), 'code_docs': Question(
# 	id='code_docs',
# 	text='18. Code Documentation',
# 	is_open=False
# ), 'code_linting': Question(
# 	id='code_linting',
# 	text='19. Linting Standards',
# 	is_open=False
# ), 'code_development': Question(
# 	id='code_development',
# 	text='20. Code Development',
# 	is_open=False
# )}, 'angewandte_chemie': {'rdp_exist': Question(
# 	id='rdp_exist',
# 	text='1. Existence of research data policy',
# 	is_open=False
# ), 'data_sharing': Question(
# 	id='data_sharing',
# 	text='3. Data sharing requirements in RDP',
# 	is_open=False
# ), 'data_fair': Question(
# 	id='data_fair',
# 	text='4. FAIR data sharing (see https://www.go-fair.org/fair-principles/ for a definition of FAIR)',
# 	is_open=False
# ), 'data_availability': Question(
# 	id='data_availability',
# 	text='2. Data availability statement',
# 	is_open=False
# ), 'data_citability': Question(
# 	id='data_citability',
# 	text='5. Citability and findability of data ',
# 	is_open=False
# ), 'data_timing': Question(
# 	id='data_timing',
# 	text='7. Timing of data release',
# 	is_open=False
# ), 'data_sharing_method': Question(
# 	id='data_sharing_method',
# 	text='8. Recommended data sharing method',
# 	is_open=False
# ), 'data_licenses': Question(
# 	id='data_licenses',
# 	text='9. Recommended/required licenses',
# 	is_open=False
# ), 'data_referee': Question(
# 	id='data_referee',
# 	text='10. Referee guidelines concerning research data',
# 	is_open=False
# ), 'data_recommended': Question(
# 	id='data_recommended',
# 	text='11. Unique policies for data types
# Please name all data types for which unique policies are recommended according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'data_required': Question(
# 	id='data_required',
# 	text='12. Unique policies for data types
# Please name all data types for which unique policies are required according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'code_required': Question(
# 	id='code_required',
# 	text='13. Code sharing requirements',
# 	is_open=False
# ), 'code_reproducibility': Question(
# 	id='code_reproducibility',
# 	text='14. Code Reproducibility',
# 	is_open=False
# ), 'code_versioning': Question(
# 	id='code_versioning',
# 	text='15. Versioning and persistent identifiers',
# 	is_open=False
# ), 'code_quality': Question(
# 	id='code_quality',
# 	text='16. Code Quality Standards',
# 	is_open=False
# ), 'code_autotest': Question(
# 	id='code_autotest',
# 	text='17. Automatic Testing',
# 	is_open=False
# ), 'code_docs': Question(
# 	id='code_docs',
# 	text='18. Code Documentation',
# 	is_open=False
# ), 'code_linting': Question(
# 	id='code_linting',
# 	text='19. Linting Standards',
# 	is_open=False
# ), 'code_development': Question(
# 	id='code_development',
# 	text='20. Code Development',
# 	is_open=False
# )}, 'chemistry_a_european_journal': {'rdp_exist': Question(
# 	id='rdp_exist',
# 	text='1. Existence of research data policy',
# 	is_open=False
# ), 'data_sharing': Question(
# 	id='data_sharing',
# 	text='3. Data sharing requirements in RDP',
# 	is_open=False
# ), 'data_fair': Question(
# 	id='data_fair',
# 	text='4. FAIR data sharing (see https://www.go-fair.org/fair-principles/ for a definition of FAIR)',
# 	is_open=False
# ), 'data_availability': Question(
# 	id='data_availability',
# 	text='2. Data availability statement',
# 	is_open=False
# ), 'data_citability': Question(
# 	id='data_citability',
# 	text='5. Citability and findability of data ',
# 	is_open=False
# ), 'data_timing': Question(
# 	id='data_timing',
# 	text='7. Timing of data release',
# 	is_open=False
# ), 'data_sharing_method': Question(
# 	id='data_sharing_method',
# 	text='8. Recommended data sharing method',
# 	is_open=False
# ), 'data_licenses': Question(
# 	id='data_licenses',
# 	text='9. Recommended/required licenses',
# 	is_open=False
# ), 'data_referee': Question(
# 	id='data_referee',
# 	text='10. Referee guidelines concerning research data',
# 	is_open=False
# ), 'data_recommended': Question(
# 	id='data_recommended',
# 	text='11. Unique policies for data types
# Please name all data types for which unique policies are recommended according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'data_required': Question(
# 	id='data_required',
# 	text='12. Unique policies for data types
# Please name all data types for which unique policies are required according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'code_required': Question(
# 	id='code_required',
# 	text='13. Code sharing requirements',
# 	is_open=False
# ), 'code_reproducibility': Question(
# 	id='code_reproducibility',
# 	text='14. Code Reproducibility',
# 	is_open=False
# ), 'code_versioning': Question(
# 	id='code_versioning',
# 	text='15. Versioning and persistent identifiers',
# 	is_open=False
# ), 'code_quality': Question(
# 	id='code_quality',
# 	text='16. Code Quality Standards',
# 	is_open=False
# ), 'code_autotest': Question(
# 	id='code_autotest',
# 	text='17. Automatic Testing',
# 	is_open=False
# ), 'code_docs': Question(
# 	id='code_docs',
# 	text='18. Code Documentation',
# 	is_open=False
# ), 'code_linting': Question(
# 	id='code_linting',
# 	text='19. Linting Standards',
# 	is_open=False
# ), 'code_development': Question(
# 	id='code_development',
# 	text='20. Code Development',
# 	is_open=False
# )}, 'angewandte_chemie_international_edition': {'rdp_exist': Question(
# 	id='rdp_exist',
# 	text='1. Existence of research data policy',
# 	is_open=False
# ), 'data_sharing': Question(
# 	id='data_sharing',
# 	text='3. Data sharing requirements in RDP',
# 	is_open=False
# ), 'data_fair': Question(
# 	id='data_fair',
# 	text='4. FAIR data sharing (see https://www.go-fair.org/fair-principles/ for a definition of FAIR)',
# 	is_open=False
# ), 'data_availability': Question(
# 	id='data_availability',
# 	text='2. Data availability statement',
# 	is_open=False
# ), 'data_citability': Question(
# 	id='data_citability',
# 	text='5. Citability and findability of data ',
# 	is_open=False
# ), 'data_timing': Question(
# 	id='data_timing',
# 	text='7. Timing of data release',
# 	is_open=False
# ), 'data_sharing_method': Question(
# 	id='data_sharing_method',
# 	text='8. Recommended data sharing method',
# 	is_open=False
# ), 'data_licenses': Question(
# 	id='data_licenses',
# 	text='9. Recommended/required licenses',
# 	is_open=False
# ), 'data_referee': Question(
# 	id='data_referee',
# 	text='10. Referee guidelines concerning research data',
# 	is_open=False
# ), 'data_recommended': Question(
# 	id='data_recommended',
# 	text='11. Unique policies for data types
# Please name all data types for which unique policies are recommended according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'data_required': Question(
# 	id='data_required',
# 	text='12. Unique policies for data types
# Please name all data types for which unique policies are required according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'code_required': Question(
# 	id='code_required',
# 	text='13. Code sharing requirements',
# 	is_open=False
# ), 'code_reproducibility': Question(
# 	id='code_reproducibility',
# 	text='14. Code Reproducibility',
# 	is_open=False
# ), 'code_versioning': Question(
# 	id='code_versioning',
# 	text='15. Versioning and persistent identifiers',
# 	is_open=False
# ), 'code_quality': Question(
# 	id='code_quality',
# 	text='16. Code Quality Standards',
# 	is_open=False
# ), 'code_autotest': Question(
# 	id='code_autotest',
# 	text='17. Automatic Testing',
# 	is_open=False
# ), 'code_docs': Question(
# 	id='code_docs',
# 	text='18. Code Documentation',
# 	is_open=False
# ), 'code_linting': Question(
# 	id='code_linting',
# 	text='19. Linting Standards',
# 	is_open=False
# ), 'code_development': Question(
# 	id='code_development',
# 	text='20. Code Development',
# 	is_open=False
# )}, 'chirality': {'rdp_exist': Question(
# 	id='rdp_exist',
# 	text='1. Existence of research data policy',
# 	is_open=False
# ), 'data_sharing': Question(
# 	id='data_sharing',
# 	text='3. Data sharing requirements in RDP',
# 	is_open=False
# ), 'data_fair': Question(
# 	id='data_fair',
# 	text='4. FAIR data sharing (see https://www.go-fair.org/fair-principles/ for a definition of FAIR)',
# 	is_open=False
# ), 'data_availability': Question(
# 	id='data_availability',
# 	text='2. Data availability statement',
# 	is_open=False
# ), 'data_citability': Question(
# 	id='data_citability',
# 	text='5. Citability and findability of data ',
# 	is_open=False
# ), 'data_timing': Question(
# 	id='data_timing',
# 	text='7. Timing of data release',
# 	is_open=False
# ), 'data_sharing_method': Question(
# 	id='data_sharing_method',
# 	text='8. Recommended data sharing method',
# 	is_open=False
# ), 'data_licenses': Question(
# 	id='data_licenses',
# 	text='9. Recommended/required licenses',
# 	is_open=False
# ), 'data_referee': Question(
# 	id='data_referee',
# 	text='10. Referee guidelines concerning research data',
# 	is_open=False
# ), 'data_recommended': Question(
# 	id='data_recommended',
# 	text='11. Unique policies for data types
# Please name all data types for which unique policies are recommended according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'data_required': Question(
# 	id='data_required',
# 	text='12. Unique policies for data types
# Please name all data types for which unique policies are required according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'code_required': Question(
# 	id='code_required',
# 	text='13. Code sharing requirements',
# 	is_open=False
# ), 'code_reproducibility': Question(
# 	id='code_reproducibility',
# 	text='14. Code Reproducibility',
# 	is_open=False
# ), 'code_versioning': Question(
# 	id='code_versioning',
# 	text='15. Versioning and persistent identifiers',
# 	is_open=False
# ), 'code_quality': Question(
# 	id='code_quality',
# 	text='16. Code Quality Standards',
# 	is_open=False
# ), 'code_autotest': Question(
# 	id='code_autotest',
# 	text='17. Automatic Testing',
# 	is_open=False
# ), 'code_docs': Question(
# 	id='code_docs',
# 	text='18. Code Documentation',
# 	is_open=False
# ), 'code_linting': Question(
# 	id='code_linting',
# 	text='19. Linting Standards',
# 	is_open=False
# ), 'code_development': Question(
# 	id='code_development',
# 	text='20. Code Development',
# 	is_open=False
# )}}, 'open journals': {'journal_of_open_source_software_(joss)': {'rdp_exist': Question(
# 	id='rdp_exist',
# 	text='1. Existence of research data policy',
# 	is_open=False
# ), 'data_sharing': Question(
# 	id='data_sharing',
# 	text='3. Data sharing requirements in RDP',
# 	is_open=False
# ), 'data_fair': Question(
# 	id='data_fair',
# 	text='4. FAIR data sharing (see https://www.go-fair.org/fair-principles/ for a definition of FAIR)',
# 	is_open=False
# ), 'data_availability': Question(
# 	id='data_availability',
# 	text='2. Data availability statement',
# 	is_open=False
# ), 'data_citability': Question(
# 	id='data_citability',
# 	text='5. Citability and findability of data ',
# 	is_open=False
# ), 'data_timing': Question(
# 	id='data_timing',
# 	text='7. Timing of data release',
# 	is_open=False
# ), 'data_sharing_method': Question(
# 	id='data_sharing_method',
# 	text='8. Recommended data sharing method',
# 	is_open=False
# ), 'data_licenses': Question(
# 	id='data_licenses',
# 	text='9. Recommended/required licenses',
# 	is_open=False
# ), 'data_referee': Question(
# 	id='data_referee',
# 	text='10. Referee guidelines concerning research data',
# 	is_open=False
# ), 'data_recommended': Question(
# 	id='data_recommended',
# 	text='11. Unique policies for data types
# Please name all data types for which unique policies are recommended according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'data_required': Question(
# 	id='data_required',
# 	text='12. Unique policies for data types
# Please name all data types for which unique policies are required according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)',
# 	is_open=False
# ), 'code_required': Question(
# 	id='code_required',
# 	text='13. Code sharing requirements',
# 	is_open=False
# ), 'code_reproducibility': Question(
# 	id='code_reproducibility',
# 	text='14. Code Reproducibility',
# 	is_open=False
# ), 'code_versioning': Question(
# 	id='code_versioning',
# 	text='15. Versioning and persistent identifiers',
# 	is_open=False
# ), 'code_quality': Question(
# 	id='code_quality',
# 	text='16. Code Quality Standards',
# 	is_open=False
# ), 'code_autotest': Question(
# 	id='code_autotest',
# 	text='17. Automatic Testing',
# 	is_open=False
# ), 'code_docs': Question(
# 	id='code_docs',
# 	text='18. Code Documentation',
# 	is_open=False
# ), 'code_linting': Question(
# 	id='code_linting',
# 	text='19. Linting Standards',
# 	is_open=False
# ), 'code_development': Question(
# 	id='code_development',
# 	text='20. Code Development',
# 	is_open=False
# )}}}

# %%
save_answers_to_yaml(
    grouped_questions,
    parent_folder="../../data/processed/all_answers",
)
# Out:
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# ../../data/processed/all_answers/ACS/the_journal_of_organic_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/journal_of_the_american_society_for_mass_spectrometry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/acs_omega.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/jacs.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# ../../data/processed/all_answers/ACS/chemrxiv.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/applied_materials_and_interfaces.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/acs_es_and_t_engineering.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/inorganic_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/jacs_au.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# ../../data/processed/all_answers/ACS/accounts_of_chemical_research.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/journal_of_medicinal_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/environmental_science_and_technology.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/accounts_of_materials_research.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/acs_energy_letters.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/the_journal_of_physical_chemistry_c.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/physics_of_fluids.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/applied_physics_reviews.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/review_of_scientific_instruments.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/physics_of_plasmas.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/chinese_journal_of_chemical_physics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/aip_advances.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/apl_photonics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/the_journal_of_chemical_physics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/structural_dynamics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/journal_of_applied_physics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/journal_of_mathematical_physics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/applied_physics_letters.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/apl_materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/AIP/low_temperature_physics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/APS/physical_review_d.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/APS/physical_review_e.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/APS/physical_review_letters.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/APS/physical_review_c.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/APS/physical_review_materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/APS/physical_review_x.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/APS/physical_review_b.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/APS/prx_quantum.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/APS/physical_review_a.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/APS/physical_review_applied.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/APS/physical_review_research.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Bentham Science/current_organic_synthesis.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Bentham Science/current_organocatalysis.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Bentham Science/current_organic_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Bentham Science/current_nanoscience.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Bentham Science/letters_in_organic_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Bentham Science/mini-reviews_in_organic_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# ../../data/processed/all_answers/Elsevier/ssrn_electronic_journal.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Elsevier/optical_materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Elsevier/applied_catalysis_b_environment_and_energy.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Elsevier/escience.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Elsevier/chemical_engineering_journal.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Elsevier/energy_storage_materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# ../../data/processed/all_answers/Elsevier/materials_today_proceedings.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Elsevier/international_journal_of_thermal_sciences.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Elsevier/composites_science_and_technology.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Frontiers/frontiers_in_chemical_engineering.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Frontiers/frontiers_in_nanotechnology.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Frontiers/frontiers_in_energy_research.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Frontiers/frontiers_in_physics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Frontiers/frontiers_in_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Frontiers/frontiers_in_bioengineering_and_biotechnology.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Frontiers/frontiers_in_materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_transactions_on_ultrasonics_ferroelectrics_and_frequency_control.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_photonics_journal.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_transactions_on_industrial_electronics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_transactions_on_transportation_electrification.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_transactions_on_applied_superconductivity.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/journal_of_lightwave_technology.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_robotics_and_automation_letters.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_sensors_letters.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_journal_of_photovoltaics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_transactions_on_dielectrics_and_electrical_insulation.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_journal_of_selected_topics_in_quantum_electronics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_transactions_on_electron_devices.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_sensors_journal.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_electron_device_letters.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IEEE/ieee_access.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IOP/journal_of_semiconductors.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IOP/nanotechnology.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IOP/journal_of_physics_energy.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IOP/journal_of_physics_photonics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IOP/iop_conference_series_materials_science_and_engineering.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IOP/smart_materials_and_structures.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IOP/quantum_science_and_technology.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IOP/2d_materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/IOP/journal_of_physics_condensed_matter.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/coatings.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/nanomaterials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/marine_drugs.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/crystals.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/polymers.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/photonics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/molbank.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/batteries.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/membranes.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/actuators.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/sensors.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/catalysts.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/molecules.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/MDPI/reactions.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Optica/photonics_research.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# ../../data/processed/all_answers/Optica/applied_optics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Optica/optics_express.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Optica/optica.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# ../../data/processed/all_answers/Optica/optical_materials_express.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# ../../data/processed/all_answers/Optica/optics_continuum.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Optica/biomedical_optics_express.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# ../../data/processed/all_answers/Optica/journal_of_the_optical_society_of_america_b.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Optica/optics_letters.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Pleiades Publishing/russian_journal_of_organic_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Pleiades Publishing/physical_mesomechanics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Pleiades Publishing/russian_journal_of_physical_chemistry_a.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Pleiades Publishing/membranes_and_membrane_technologies.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Pleiades Publishing/atmospheric_and_oceanic_optics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Pleiades Publishing/russian_journal_of_general_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Pleiades Publishing/journal_of_experimental_and_theoretical_physics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Pleiades Publishing/physics_of_metals_and_metallography.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Pleiades Publishing/russian_journal_of_inorganic_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/RSC/energy_advances.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/RSC/environmental_science_nano.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/RSC/physical_chemistry_chemical_physics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/RSC/dalton_transactions.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/RSC/energy_and_environmental_science.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/RSC/digital_discovery.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/RSC/nanoscale_advances.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/RSC/journal_of_materials_chemistry_a.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/RSC/chemical_communications.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Springer Nature/journal_of_materials_science_materials_in_electronics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Springer Nature/nano-micro_letters.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Springer Nature/materials_science.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# ../../data/processed/all_answers/Springer Nature/high_energy_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Springer Nature/nature.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Springer Nature/nature_energy.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Springer Nature/biomedical_microdevices.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# Warning: This question has a single answer
# ../../data/processed/all_answers/Springer Nature/scientific_data.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Springer Nature/nature_communications.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Springer Nature/scientific_reports.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Springer Nature/medicinal_chemistry_research.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/molecular_crystals_and_liquid_crystals.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/waves_in_random_and_complex_media.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/analytical_letters.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/journal_of_asian_ceramic_societies.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/nanotoxicology.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/advanced_composite_materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/international_journal_of_nanomedicine.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/ferroelectrics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/journal_of_macromolecular_science_part_b.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/polycyclic_aromatic_compounds.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/liquid_crystals.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/materials_research_letters.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/molecular_physics.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/green_chemistry_letters_and_reviews.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Taylor & Francis/science_and_technology_of_advanced_materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/carbon_energy.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/small.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/batteries_and_supercaps.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/microscopy_research_and_technique.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/journal_of_physical_organic_chemistry.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/advanced_materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/infomat.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/chemistryselect.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/advanced_energy_materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/advanced_functional_materials.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/ce-papers.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/angewandte_chemie.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/chemistry_a_european_journal.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/angewandte_chemie_international_edition.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/Wiley/chirality.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/open journals/journal_of_open_source_software_(joss).yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.

# %% [markdown]
# After doing this, the `.get_final_answer()` method returns the correct answer.
