# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from daemon_analysis_tools.io.csv_handler import load_and_process_csv
from daemon_analysis_tools.io.yaml_handler import save_answers_to_yaml, load_answers_from_yaml
from daemon_analysis_tools.processing.grouper import group_questions_by_journal
from daemon_analysis_tools.services.discrepancy_resolver import resolve_discrepancy

# %%
! pwd
# Out:
# /home/lukas/Science/Projects/DAEMON_open_data_policies/Journal-Research-Data-Policy/notebooks/fix_inconsistencies

# %% [markdown]
# Load and process data:
# - Group answers by publisher and journal, trying to uniform names written in slightly different ways.
# - Store in a DataFrame

# %%
data = load_and_process_csv("../../data/raw/rdp.csv")

# %% [markdown]
# Get a `dict` labeled by publisher names of `dict`s labeled by journal names of `dict`s of `Question` instances. The `.answer` attribute contains the answers given by the respondents and the explanations text to motivate it.

# %%
question_metadata_file = "../../data/metadata/question_metadata.yaml"

grouped_questions = group_questions_by_journal(data, question_metadata_file)

# %% [markdown]
# ## Resolve discrepancies

# %% [markdown]
# The `Question` class has a `.resolve_discrepancies` method which updates `Question.anwsers` with the correct answer.

# %% [markdown]
# For example, let's consider IOP's 2D Materials. Question 7 has discrepancies.

# %%
for journal, data in grouped_questions["ACS"].items():
    print("#############################################################")
    print(journal)
    for question, answer in data.items():
        if answer.has_discrepancies():
            answer.print_qa()
# Out:
# #############################################################
# accounts_of_chemical_research
# ...
# #############################################################
# accounts_of_materials_research
# 4. FAIR data sharing (see https://www.go-fair.org/fair-principles/ for a definition of FAIR)
#   Resp. 0:
#     Answer: Public data sharing on a FAIR repository required only for specific types of data (e.g. genetic data has to be shared on a FAIR repository but no other data).
#     Explanation: Choosing an Appropriate Data Repository
#
# Where possible, ACS recommends authors deposit data in discipline-specific, community-recognized repositories or in generalist repositories when no community resource is available. Authors should consult the journal Author Guidelines for specific repository recommendations or requirements for data types.
#
# ...

# %% [markdown]
# Inconsistencies can be removed manually, passing the index of the correct respondent.

# %%
for j in ["accounts_of_materials_research"]:
    for i in [4, 7, 8, 9]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=1,
            discrepancy_reason="Language understanding",
        )
    
    for i in [11, 12]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=1,
            discrepancy_reason="Formatting",
        )

for j in ["acs_energy_letters"]:
    for i in [7, 8]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )
    
    for i in [11, 12]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=1,
            discrepancy_reason="Formatting",
        )

for j in ["applied_materials_and_interfaces"]:
    for i in [4, 5, 7, 8]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=1,
            discrepancy_reason="Text not found",
        )

for j in ["acs_es_and_t_engineering"]:
    for i in [4, 5, 8]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )

    for i in [7]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Language understanding",
        )
    
    for i in [11, 12]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=1,
            discrepancy_reason="Formatting",
        )

for j in ["acs_omega"]:
    for i in [3, 4, 5, 7]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=1,
            discrepancy_reason="Text not found",
        )

    for i in [8]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Language understanding",
        )
    
    for i in [11, 12]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=1,
            discrepancy_reason="Formatting",
        )

for j in ["environmental_science_and_technology"]:
    for i in [2, 4, 5, 7]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )

    for i in [8]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Language understanding",
        )
    
    for i in [11, 12, 13, 14, 16]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )

for j in ["inorganic_chemistry"]:
    for i in [5, 8, 9]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )

    for i in [7]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=1,
            discrepancy_reason="Text not found",
        )
    
    for i in [11, 12]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )
    
    for i in [13, 15, 16]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )

for j in ["jacs"]:
    for i in [5, 8, 9, 11, 12]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )
    
    for i in [7]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Language understanding",
        )

for j in ["jacs_au"]:
    for i in [5, 7, 8, 9, 11, 12]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )

for j in ["journal_of_medicinal_chemistry"]:
    for i in [4, 5, 8, 11, 12, 13]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )
    
    for i in [7]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Language understanding",
        )

for j in ["journal_of_the_american_society_for_mass_spectrometry"]:
    for i in [4, 5, 8, 9, 11]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )
    
    for i in [7]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Language understanding",
        )
    
    for i in [12]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Formatting",
        )

for j in ["the_journal_of_physical_chemistry_c"]:
    for i in [4, 5, 8, 11, 12, 13]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Text not found",
        )
    
    for i in [7]:
        resolve_discrepancy(
            grouped_questions["ACS"][j][i],
            correct_answer=0,
            discrepancy_reason="Language understanding",
        )

# %%
for journal, data in grouped_questions["ACS"].items():
    print("#############################################################")
    print(journal)
    for question, answer in data.items():
        if answer.has_discrepancies() and answer.correct_answer is None:
            answer.print_qa()
# Out:
# #############################################################
# accounts_of_chemical_research
# ...
# #############################################################
# accounts_of_materials_research
# #############################################################
# acs_energy_letters
# #############################################################
# acs_es_and_t_engineering
# #############################################################
# acs_omega
# #############################################################
# applied_materials_and_interfaces
# 11. Unique policies for data types
# Please name all data types for which unique policies are recommended according to the RDP (Please separate all data types be semicolon, e.g. crystal structures; Protein sequence)
#   Resp. 0:
#     Answer: nan
#     Explanation:
#   Resp. 1:
#     Answer: no text.
#     Explanation:
# 12. Unique policies for data types
# ...

# %%
save_answers_to_yaml(
    grouped_questions,
    parent_folder="../../data/processed/all_answers",
    save_only=["ACS"],
)
# Out:
# ...
# ../../data/processed/all_answers/ACS/accounts_of_chemical_research.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/accounts_of_materials_research.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/acs_energy_letters.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/acs_es_and_t_engineering.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ../../data/processed/all_answers/ACS/acs_omega.yaml already exists. No data was written to prevent overwriting files modified by users. Manually delete this file if necessary.
# ...

# %% [markdown]
# After doing this, the `.get_final_answer()` method returns the correct answer.
