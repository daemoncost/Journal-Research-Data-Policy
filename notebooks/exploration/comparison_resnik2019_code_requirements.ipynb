# %% [markdown]
# # Supplementary: Comparison with Resnik et al. (2019)
#
# This notebook was used to identify a subset of physics journals that were previously identified as requiring code deposition and check whether this requirement still holds under our stricter interpretation.

# %%
import pandas as pd
#journals to compare the code publication requirement to resnik et al. 2019 were selected with the following code
#the csv can be obtained from https://zenodo.org/records/2595591
data = pd.read_csv('if-discipline-datasharing-policy-rawdata-1.0.0.csv')
data = data[(data['code_deposit'] == True) & (data['TypeofScience'] == 'P')]
print(data['URL'])
